# %%
import models
import scatter
import regions
import plot
import pandas as pd

# %%
data = pd.read_csv("weatherAUS.csv")
data = regions.regionalize(data)
regions.regionplot(data,"Victoria")
# Out:
# /Users/richardmatthias/miniconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/richardmatthias/miniconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plot.yearplots(data)
plot.seasonplot(data)

# %%
#These onehots and features may be changed according to how the user interprets the data
onehots=["Region","WindGustDir","Location"]
features=["MinTemp","MaxTemp","Rainfall","WindGustSpeed","Humidity9am","Humidity3pm","Pressure9am","Pressure3pm","Temp9am","Temp3pm"]
cleanx,cleany,cleanf = models.learningProcessor(data,features,onehots)
model = models.trainModel(cleanx,cleany)
# Out:
# /Users/richardmatthias/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /Users/richardmatthias/miniconda3/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# {'Logistic': 0.848783232522155, 'Linear': 0.847657898438599, 'SVM': 0.8248698832465888, 'KNN': 0.8350682233788156}

# %%
scatter.scatter(model,cleanx,cleany)
